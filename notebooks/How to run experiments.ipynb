# %%
# !bash ./scripts/preprocess_energy_mix.sh
# Out:
# Index(['timestamp', 'nuclear', 'geothermal', 'biomass', 'coal', 'wind',
#        'solar', 'hydro', 'gas', 'oil', 'unknown'],
#       dtype='object')
# Index(['timestamp', 'nuclear', 'geothermal', 'biomass', 'coal', 'wind',
#        'solar', 'hydro', 'gas', 'oil', 'unknown'],
#       dtype='object')
# Index(['timestamp', 'nuclear', 'geothermal', 'biomass', 'coal', 'wind',
#        'solar', 'hydro', 'gas', 'oil', 'unknown'],
#       dtype='object')
# Index(['timestamp', 'nuclear', 'geothermal', 'biomass', 'coal', 'wind',
#        'solar', 'hydro', 'gas', 'oil', 'unknown'],
#       dtype='object')
# Index(['timestamp', 'nuclear', 'geothermal', 'biomass', 'coal', 'wind',
#        'solar', 'hydro', 'gas', 'oil', 'unknown'],
#       dtype='object')
# Index(['timestamp', 'nuclear', 'geothermal', 'biomass', 'coal', 'wind',
#        'solar', 'hydro', 'gas', 'oil', 'unknown'],
#       dtype='object')
# Index(['timestamp', 'nuclear', 'geothermal', 'biomass', 'coal', 'wind',
# ...

# %%
# !bash ./scripts/generate_scenario.sh
# Out:
# Run script saved to ./experiments/run_scenario_1_winter.sh for season winter.
# Run script saved to ./experiments/run_scenario_1_spring.sh for season spring.
# Run script saved to ./experiments/run_scenario_1_summer.sh for season summer.
# Run script saved to ./experiments/run_scenario_1_autumn.sh for season autumn.
# Run script saved to ./experiments/run_scenario_2_winter.sh for season winter.
# Run script saved to ./experiments/run_scenario_2_spring.sh for season spring.
# Run script saved to ./experiments/run_scenario_2_summer.sh for season summer.
# Run script saved to ./experiments/run_scenario_2_autumn.sh for season autumn.

# %%
# !tar -cvzf experiments_in.tar.gz experiments/in

# %%
# !python -m preprocessing.scenario --n 2 --bash
