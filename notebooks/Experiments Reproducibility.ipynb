# %% [markdown]
# # Experiments Reproducibility

# %% [markdown]
# Decompress the archive with all the historical energy mix data.

# %%
# !tar -cvzf data/energy_mix/historical.zip data/energy_mix/historical

# %% [markdown]
# Otherwise download the data from the respective sources abailable in the README.md file. Create the folder data/energy_mix/raw and move all the filse in such folder.
# Then execute the following script to get the csv in a standardized format.

# %%
# !python -m preprocessing.annual_energy_mix_std --uk --sw --de --pjm --ercot --caiso --miso

# %% [markdown]
# Preprocess the energy mix data to minimc the forecast error.

# %%
# !bash ./scripts/preprocess_energy_mix.sh

# %% [markdown]
# Generate the scenarios based on the .yaml files in ./experiments/scenarios. The script populate the folder ./experiments/in with the sustainability profiles of each region considering the input configuration. You can consider more scenario adding the .yaml file and editing ./scripts/generate_scenario.sh

# %%
# !bash ./scripts/generate_scenario.sh

# %% [markdown]
# Run the script generated by the previous command. Note that the experiments take long time to execute and generate a lot of data. For each scenario, a summary of the results is provided in this repository. Check out the folder ./experiments/out/
