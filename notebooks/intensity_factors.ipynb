# %%
import src.parameters as parameters

# %%
# Out:
# {'carbon': {'nuclear': 12,
#   'geothermal': 38,
#   'biomass': 485.0,
#   'coal': 820,
#   'wind': 11.5,
#   'solar': 38.666666666666664,
#   'hydro': 24,
#   'gas': 490,
#   'oil': 720,
#   'unknown': np.float64(293.2407407407407)},
#  'water': {'nuclear': 1.95705697,
#   'geothermal': 5.827260154,
#   'biomass': 1.145465066,
#   'coal': 1.8003992330769232,
#   'wind': 0.0,
#   'solar': 1.38546006,
#   'hydro': 17.00027631,
#   'gas': 1.0996616049999999,
#   'unknown': np.float64(3.7769474247596158),
#   'oil': np.float64(3.7769474247596158)},
#  'land_use': {'nuclear': 7.1e-05,
#   'geothermal': 0.00045000000000000004,
#   'biomass': 0.29065,
#   'coal': 0.01,
#   'wind': 0.06065,
#   'solar': 0.0165,
#   'hydro': 0.006500000000000001,
#   'gas': 0.011550000000000001,
#   'oil': 0.011550000000000001,
#   'unknown': np.float64(0.04532455555555556)}}

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# Data from the image
factors = ['CI', 'EWIF', 'ELIF']
sources = ['wind', 'nuclear', 'hydro', 'geothermal', 'solar', 'unknown', 'biomass', 'gas', 'oil', 'coal']

# %%
for factor, coefficients in parameters.coefficients_raw.items():
    print(factor)
    for source in sources:
        print(f"  {source}: {coefficients[source]}")
        
        print(f"  normalized: {coefficients[source]/max(coefficients.values())}")
# Out:
# carbon
#   wind: 11.5
#   normalized: 0.01402439024390244
#   nuclear: 12
#   normalized: 0.014634146341463415
#   hydro: 24
#   normalized: 0.02926829268292683
#   geothermal: 38
#   normalized: 0.046341463414634146
#   solar: 38.666666666666664
#   normalized: 0.04715447154471544
#   unknown: 293.2407407407407
#   normalized: 0.3576106594399277
#   biomass: 485.0
#   normalized: 0.5914634146341463
#   gas: 490
#   normalized: 0.5975609756097561
#   oil: 720
#   normalized: 0.8780487804878049
#   coal: 820
#   normalized: 1.0
# water
#   wind: 0.0
#   normalized: 0.0
#   nuclear: 1.95705697
#   normalized: 0.11511912714317524
#   hydro: 17.00027631
#   normalized: 1.0
#   geothermal: 5.827260154
#   normalized: 0.34277443776441774
#   solar: 1.38546006
#   normalized: 0.08149632598530394
#   unknown: 3.7769474247596158
#   normalized: 0.22216976688419576
#   biomass: 1.145465066
#   normalized: 0.06737920285014473
#   gas: 1.0996616049999999
#   normalized: 0.06468492540636829
#   oil: 3.7769474247596158
#   normalized: 0.22216976688419576
#   coal: 1.8003992330769232
#   normalized: 0.10590411592415601
# land_use
#   wind: 0.06065
#   normalized: 0.20867022191639428
#   nuclear: 7.1e-05
#   normalized: 0.00024428006193015657
#   hydro: 0.006500000000000001
#   normalized: 0.022363667641493206
#   geothermal: 0.00045000000000000004
#   normalized: 0.0015482539136418374
#   solar: 0.0165
#   normalized: 0.056769310166867364
#   unknown: 0.04532455555555556
#   normalized: 0.1559420456065906
#   biomass: 0.29065
#   normalized: 1.0
#   gas: 0.011550000000000001
#   normalized: 0.039738517116807155
#   oil: 0.011550000000000001
#   normalized: 0.039738517116807155
#   coal: 0.01
#   normalized: 0.03440564252537416

# %%
data = [
    [0.0039, 0.0041, 0.0082, 0.013, 0.013, 0.1, 0.17, 0.17, 0.25, 0.28],
    [0, 0.052, 0.45, 0.15, 0.037, 0.1, 0.03, 0.029, 0.1, 0.048],
    [0.13, 0.00016, 0.014, 0.00099, 0.036, 0.1, 0.64, 0.025, 0.025, 0.022],
]

data = np.array(data)

fig, ax = plt.subplots(figsize=(12, 4), dpi=300)

# Custom colormap: light yellow to pink/red
cmap = mcolors.LinearSegmentedColormap.from_list('custom', ['#f9f0a8', '#f4a582', '#d6604d'], N=256)

im = ax.imshow(data, cmap=cmap, aspect='auto', vmin=0, vmax=0.7)

# Colorbar
cbar = fig.colorbar(im, ax=ax, fraction=0.03, pad=0.02)
cbar.set_label('Intensity', fontsize=11)
cbar.ax.tick_params(labelsize=9)

# Ticks
ax.set_xticks(range(len(sources)))
ax.set_xticklabels(sources, rotation=45, ha='right', fontsize=10)
ax.set_yticks(range(len(factors)))
ax.set_yticklabels(factors, fontsize=11, fontweight='bold')

# Labels
ax.set_xlabel('Energy Source', fontsize=12, labelpad=10)
ax.set_ylabel('Factor', fontsize=12, labelpad=10)
ax.set_title('Normalized Intensity Factors by Energy Source (ordered by carbon)',
             fontsize=13, fontweight='bold', pad=14)

# Annotate cells
for i in range(len(factors)):
    for j in range(len(sources)):
        val = data[i, j]
        # Format value
        if val == 0:
            text = '0'
        elif val < 0.001:
            text = f'{val:.5f}'
        elif val < 0.01:
            text = f'{val:.4f}'
        elif val < 0.1:
            text = f'{val:.3f}'
        else:
            text = f'{val:.2g}'
        # Choose text color based on background intensity
        color = 'black' if val < 0.4 else 'white'
        ax.text(j, i, text, ha='center', va='center', fontsize=8.5,
                color=color, fontweight='medium')

plt.tight_layout()
plt.savefig('intensity_factors.pdf', format='pdf', bbox_inches='tight', dpi=300)
print("Saved as intensity_factors.pdf")
